# %%
#importing the os module
import os
import queue as q

#to get the current working directory
directory = os.getcwd()

print(directory)

filepath = directory+"/input.txt"  #CHANGE HERE!!
print(filepath)

#filepath is just the path + name
thefile=open(filepath)
#throw the raw format into variable rawdata
rawdata=thefile.read()
#split by "\n", which stands for new line
datafromfile = rawdata.split("\n")








#moving forward, you can use this sheet to get the input.
print(f"datafromfile is now {datafromfile}")


#hint 1 - there are occasional "", this is a marker for the next set.
#you will need to go through *every item* in datafromfile and sum them up. 
#everytime you hit a "", that's the end of the calorie sum
#you can call on an item by using datafromfile[0], datafromfile[1]....
counter = 0
while counter < len(datafromfile):
    print(f"the counter value is now {counter} and the list item is {datafromfile[counter]}")
    counter = counter + 1


#hint 2 - you're going to want to create another list. 
#every time you hit a "", you want to insert the summed calorie values into that new list
# Out:
# /Users/leot/Desktop/Leo Python/Advent_of_Code_2022/Day_01
# /Users/leot/Desktop/Leo Python/Advent_of_Code_2022/Day_01/input.txt
# ...
